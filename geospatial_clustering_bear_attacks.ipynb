# %% [markdown]
# Geospatial Data Clustering for Fatal Bear Attacks in North America
#
# Density-based spatial clustering (DBSCAN) - Unsupervised ML methods
#
# Dataset: https://www.kaggle.com/datasets/danela/fatal-bear-attacks-north-america/data
#
# Tutorial referenced in code: https://geoffboeing.com/2014/08/clustering-to-reduce-spatial-data-set-size/

# %%
import pandas as pd, numpy as np, matplotlib.pyplot as plt
from sklearn.cluster import DBSCAN
from geopy.distance import great_circle
from shapely.geometry import MultiPoint
import geopandas
import matplotlib.pyplot as plt
import folium
import mapclassify

# %%
url = 'https://raw.githubusercontent.com/A-Bin1/Data-Science-Misc/main/bear_attacks_geospatial_dataset.csv'
bear_df = pd.read_csv(url)
coords = bear_df[['Latitude', 'Longitude']].to_numpy()

# %%
coords[0:10]
# Out:
# array([[  66.53416   ,  -83.88217   ],
#        [  61.16723   ,  -93.85015   ],
#        [  62.808913  ,  -92.087741  ],
#        [  69.7428    , -163.01125   ],
#        [  58.767755  ,  -94.163998  ],
#        [  68.360605  , -133.720367  ],
#        [  58.767755  ,  -94.163998  ],
#        [  46.1334    ,  -79.53293   ],
#        [  64.8080879 , -151.00415781],
#        [  60.98663   , -149.51277   ]])

# %%
def create_clusters(cds, km):
    earth_kms_per_radian = 6371 #radius of the earth
    epsilon = km / earth_kms_per_radian #convert km to radians
    db = DBSCAN(eps=epsilon, min_samples=1, algorithm='ball_tree', metric='haversine').fit(np.radians(cds))
    cluster_labels = db.labels_
    num_clusters = len(set(cluster_labels))
    clusters = pd.Series([cds[cluster_labels == n] for n in range(num_clusters)])
    print('Number of clusters: {}'.format(num_clusters))
    return clusters

# %%
create_clusters(coords,100)
# Out:
# Number of clusters: 85
# 0             [[66.53416000000004, -83.88216999999997]]
# 1                      [[61.16723000000008, -93.85015]]
# 2             [[62.80891300000008, -92.08774099999994]]
# 3            [[69.74280000000005, -163.01124999999996]]
# 4     [[58.76775500000008, -94.16399799999994], [58....
#                             ...
# 80           [[41.72244511900004, -111.74354625399997]]
# 81          [[36.578550000000064, -118.29341999999995]]
# 82    [[34.01158000000004, -118.49226999999996], [34...
# 83           [[38.45047000000005, -123.12944999999996]]
# 84           [[34.87404000000004, -118.89168999999998]]
# Length: 85, dtype: object

# %%
clusters = create_clusters(coords,100)
# Out:
# Number of clusters: 85

# %%
def get_centermost_point(cluster):
    centroid = (MultiPoint(cluster).centroid.x, MultiPoint(cluster).centroid.y)
    centermost_point = min(cluster, key=lambda point: great_circle(point, centroid).m)
    return tuple(centermost_point)

centermost_points = clusters.map(get_centermost_point)

# %%
centermost_points.head()
# Out:
# 0     (66.53416000000004, -83.88216999999997)
# 1              (61.16723000000008, -93.85015)
# 2     (62.80891300000008, -92.08774099999994)
# 3    (69.74280000000005, -163.01124999999996)
# 4     (58.76775500000008, -94.16399799999994)
# dtype: object

# %%
cdf = pd.DataFrame(centermost_points)
cdf = cdf.rename(columns = {0 :'Location'})
cdf.head()
# Out:
#                                    Location
# 0   (66.53416000000004, -83.88216999999997)
# 1            (61.16723000000008, -93.85015)
# 2   (62.80891300000008, -92.08774099999994)
# 3  (69.74280000000005, -163.01124999999996)
# 4   (58.76775500000008, -94.16399799999994)

# %%
new_col_list = ['Latitude','Longitude']
for n,col in enumerate(new_col_list):
    cdf[col] = cdf['Location'].apply(lambda Location: Location[n])

cldf = cdf.drop('Location',axis=1)

# %%
cldf.head()
# Out:
#     Latitude   Longitude
# 0  66.534160  -83.882170
# 1  61.167230  -93.850150
# 2  62.808913  -92.087741
# 3  69.742800 -163.011250
# 4  58.767755  -94.163998

# %% [markdown]
# Compare and Contrast full list of coordinates to clustered data.

# %%
geodf = geopandas.GeoDataFrame(
    bear_df, geometry=geopandas.points_from_xy(bear_df.Longitude, bear_df.Latitude), crs="EPSG:4327"
)

# %%
len(geodf)
# Out:
# 156

# %%
geodf.explore()
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_18fd3b556302cb89174ac472fb1a233d {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#
#                     &lt;style&gt;
#                         .foliumtooltip {
#
#                         }
#                        .foliumtooltip table{
#                             margin: auto;
#                         }
#                         .foliumtooltip tr{
#                             text-align: left;
#                         }
#                         .foliumtooltip th{
#                             padding: 2px; padding-right: 8px;
#                         }
#                     &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_18fd3b556302cb89174ac472fb1a233d&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_18fd3b556302cb89174ac472fb1a233d = L.map(
#                 &quot;map_18fd3b556302cb89174ac472fb1a233d&quot;,
#                 {
#                     center: [49.19531886717293, -114.91833599999995],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 10,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#             L.control.scale().addTo(map_18fd3b556302cb89174ac472fb1a233d);
#
#
#
#
#
#             var tile_layer_09fe85e78387d5bbfa9c28c7de878f7e = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca target=\&quot;_blank\&quot; href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             );
#
#
#                 tile_layer_09fe85e78387d5bbfa9c28c7de878f7e.addTo(map_18fd3b556302cb89174ac472fb1a233d);
#
#             map_18fd3b556302cb89174ac472fb1a233d.fitBounds(
#                 [[28.647837734345817, -163.01124999999996], [69.74280000000005, -66.82542199999995]],
#                 {}
#             );
#
#
#         function geo_json_5c8bada54382a45451679c567f4f5464_styler(feature) {
#             switch(feature.id) {
#                 default:
#                     return {&quot;fillOpacity&quot;: 0.5, &quot;weight&quot;: 2};
#             }
#         }
#         function geo_json_5c8bada54382a45451679c567f4f5464_highlighter(feature) {
#             switch(feature.id) {
#                 default:
#                     return {&quot;fillOpacity&quot;: 0.75};
#             }
#         }
#         function geo_json_5c8bada54382a45451679c567f4f5464_pointToLayer(feature, latlng) {
#             var opts = {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;#3388ff&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;#3388ff&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 2, &quot;stroke&quot;: true, &quot;weight&quot;: 3};
#
#             let style = geo_json_5c8bada54382a45451679c567f4f5464_styler(feature)
#             Object.assign(opts, style)
#
#             return new L.CircleMarker(latlng, opts)
#         }
#
#         function geo_json_5c8bada54382a45451679c567f4f5464_onEachFeature(feature, layer) {
#             layer.on({
#                 mouseout: function(e) {
#                     if(typeof e.target.setStyle === &quot;function&quot;){
#                         geo_json_5c8bada54382a45451679c567f4f5464.resetStyle(e.target);
#                     }
#                 },
#                 mouseover: function(e) {
#                     if(typeof e.target.setStyle === &quot;function&quot;){
#                         const highlightStyle = geo_json_5c8bada54382a45451679c567f4f5464_highlighter(e.target.feature)
#                         e.target.setStyle(highlightStyle);
#                     }
#                 },
#             });
#         };
#         var geo_json_5c8bada54382a45451679c567f4f5464 = L.geoJson(null, {
#                 onEachFeature: geo_json_5c8bada54382a45451679c567f4f5464_onEachFeature,
#
#                 style: geo_json_5c8bada54382a45451679c567f4f5464_styler,
#                 pointToLayer: geo_json_5c8bada54382a45451679c567f4f5464_pointToLayer,
#         });
#
#         function geo_json_5c8bada54382a45451679c567f4f5464_add (data) {
#             geo_json_5c8bada54382a45451679c567f4f5464
#                 .addData(data);
#         }
#             geo_json_5c8bada54382a45451679c567f4f5464_add({&quot;bbox&quot;: [-163.01124999999996, 28.647837734345817, -66.82542199999995, 69.74280000000005], &quot;features&quot;: [{&quot;bbox&quot;: [-83.88216999999997, 66.53416000000004, -83.88216999999997, 66.53416000000004], &quot;geometry&quot;: {&quot;coordinates&quot;: [-83.88216999999997, 66.53416000000004], &quot;type&quot;: &quot;Point&quot;}, &quot;id&quot;: &quot;0&quot;, &quot;properties&quot;: {&quot;Age&quot;: &quot; 33&quot;, &quot;Bear&quot;: &quot;Polar&quot;, &quot;Date&quot;: &quot;August 23, 2018&quot;, &quot;Details&quot;: &quot;Three men from Naujaat, whose boat had broken down, were having tea on the mornin

# %%
geo_clusterdf = geopandas.GeoDataFrame(
    cldf, geometry=geopandas.points_from_xy(cldf.Longitude, cldf.Latitude), crs="EPSG:4327"
)

# %%
len(geo_clusterdf)
# Out:
# 85

# %%
geo_clusterdf.explore()
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_6d1e9b0c33a5f94f35128f994a942ed6 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#
#                     &lt;style&gt;
#                         .foliumtooltip {
#
#                         }
#                        .foliumtooltip table{
#                             margin: auto;
#                         }
#                         .foliumtooltip tr{
#                             text-align: left;
#                         }
#                         .foliumtooltip th{
#                             padding: 2px; padding-right: 8px;
#                         }
#                     &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_6d1e9b0c33a5f94f35128f994a942ed6&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_6d1e9b0c33a5f94f35128f994a942ed6 = L.map(
#                 &quot;map_6d1e9b0c33a5f94f35128f994a942ed6&quot;,
#                 {
#                     center: [49.19531886717293, -114.91833599999995],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 10,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#             L.control.scale().addTo(map_6d1e9b0c33a5f94f35128f994a942ed6);
#
#
#
#
#
#             var tile_layer_cca40c29043c3213e7f957011b82d1a5 = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca target=\&quot;_blank\&quot; href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             );
#
#
#                 tile_layer_cca40c29043c3213e7f957011b82d1a5.addTo(map_6d1e9b0c33a5f94f35128f994a942ed6);
#
#             map_6d1e9b0c33a5f94f35128f994a942ed6.fitBounds(
#                 [[28.647837734345817, -163.01124999999996], [69.74280000000005, -66.82542199999995]],
#                 {}
#             );
#
#
#         function geo_json_91ab4c04e96e4fc8a62c3d63191e3f94_styler(feature) {
#             switch(feature.id) {
#                 default:
#                     return {&quot;fillOpacity&quot;: 0.5, &quot;weight&quot;: 2};
#             }
#         }
#         function geo_json_91ab4c04e96e4fc8a62c3d63191e3f94_highlighter(feature) {
#             switch(feature.id) {
#                 default:
#                     return {&quot;fillOpacity&quot;: 0.75};
#             }
#         }
#         function geo_json_91ab4c04e96e4fc8a62c3d63191e3f94_pointToLayer(feature, latlng) {
#             var opts = {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;#3388ff&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;#3388ff&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 2, &quot;stroke&quot;: true, &quot;weight&quot;: 3};
#
#             let style = geo_json_91ab4c04e96e4fc8a62c3d63191e3f94_styler(feature)
#             Object.assign(opts, style)
#
#             return new L.CircleMarker(latlng, opts)
#         }
#
#         function geo_json_91ab4c04e96e4fc8a62c3d63191e3f94_onEachFeature(feature, layer) {
#             layer.on({
#                 mouseout: function(e) {
#                     if(typeof e.target.setStyle === &quot;function&quot;){
#                         geo_json_91ab4c04e96e4fc8a62c3d63191e3f94.resetStyle(e.target);
#                     }
#                 },
#                 mouseover: function(e) {
#                     if(typeof e.target.setStyle === &quot;function&quot;){
#                         const highlightStyle = geo_json_91ab4c04e96e4fc8a62c3d63191e3f94_highlighter(e.target.feature)
#                         e.target.setStyle(highlightStyle);
#                     }
#                 },
#             });
#         };
#         var geo_json_91ab4c04e96e4fc8a62c3d63191e3f94 = L.geoJson(null, {
#                 onEachFeature: geo_json_91ab4c04e96e4fc8a62c3d63191e3f94_onEachFeature,
#
#                 style: geo_json_91ab4c04e96e4fc8a62c3d63191e3f94_styler,
#                 pointToLayer: geo_json_91ab4c04e96e4fc8a62c3d63191e3f94_pointToLayer,
#         });
#
#         function geo_json_91ab4c04e96e4fc8a62c3d63191e3f94_add (data) {
#             geo_json_91ab4c04e96e4fc8a62c3d63191e3f94
#                 .addData(data);
#         }
#             geo_json_91ab4c04e96e4fc8a62c3d63191e3f94_add({&quot;bbox&quot;: [-163.01124999999996, 28.647837734345817, -66.82542199999995, 69.74280000000005], &quot;features&quot;: [{&quot;bbox&quot;: [-83.88216999999997, 66.53416000000004, -83.88216999999997, 66.53416000000004], &quot;geometry&quot;: {&quot;coordinates&quot;: [-83.88216999999997, 66.53416000000004], &quot;type&quot;: &quot;Point&quot;}, &quot;id&quot;: &quot;0&quot;, &quot;properties&quot;: {&quot;Latitude&quot;: 66.53416000000004, &quot;Longitude&quot;: -83.88216999999997}, &quot;type&quot;: &quot;Feature&quot;}, {&quot;bbox&quot;: [-93.85015, 61.16723000000008, -93.85015, 61.16723000000008], &quot;geometry&quot;

# %%
#simulate overlays of the datasets
def plot_overlay(how):
    new = geopandas.overlay(geodf, geo_clusterdf, how=how, keep_geom_type=None, make_valid=True)
    return new.explore()

# %%
#'intersection',
# 'union',
# 'identity',
# 'symmetric_difference',
# 'difference' 


plot_overlay('intersection')
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_17e39a1f01286396e62a68265d29fac6 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#
#                     &lt;style&gt;
#                         .foliumtooltip {
#
#                         }
#                        .foliumtooltip table{
#                             margin: auto;
#                         }
#                         .foliumtooltip tr{
#                             text-align: left;
#                         }
#                         .foliumtooltip th{
#                             padding: 2px; padding-right: 8px;
#                         }
#                     &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_17e39a1f01286396e62a68265d29fac6&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_17e39a1f01286396e62a68265d29fac6 = L.map(
#                 &quot;map_17e39a1f01286396e62a68265d29fac6&quot;,
#                 {
#                     center: [49.19531886717293, -114.91833599999995],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 10,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#             L.control.scale().addTo(map_17e39a1f01286396e62a68265d29fac6);
#
#
#
#
#
#             var tile_layer_5bcf3ff18b5d02083d226b4f69b0a2fc = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca target=\&quot;_blank\&quot; href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             );
#
#
#                 tile_layer_5bcf3ff18b5d02083d226b4f69b0a2fc.addTo(map_17e39a1f01286396e62a68265d29fac6);
#
#             map_17e39a1f01286396e62a68265d29fac6.fitBounds(
#                 [[28.647837734345817, -163.01124999999996], [69.74280000000005, -66.82542199999995]],
#                 {}
#             );
#
#
#         function geo_json_49305be1b31f0cf032f0622a8b3d09a9_styler(feature) {
#             switch(feature.id) {
#                 default:
#                     return {&quot;fillOpacity&quot;: 0.5, &quot;weight&quot;: 2};
#             }
#         }
#         function geo_json_49305be1b31f0cf032f0622a8b3d09a9_highlighter(feature) {
#             switch(feature.id) {
#                 default:
#                     return {&quot;fillOpacity&quot;: 0.75};
#             }
#         }
#         function geo_json_49305be1b31f0cf032f0622a8b3d09a9_pointToLayer(feature, latlng) {
#             var opts = {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;#3388ff&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;#3388ff&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 2, &quot;stroke&quot;: true, &quot;weight&quot;: 3};
#
#             let style = geo_json_49305be1b31f0cf032f0622a8b3d09a9_styler(feature)
#             Object.assign(opts, style)
#
#             return new L.CircleMarker(latlng, opts)
#         }
#
#         function geo_json_49305be1b31f0cf032f0622a8b3d09a9_onEachFeature(feature, layer) {
#             layer.on({
#                 mouseout: function(e) {
#                     if(typeof e.target.setStyle === &quot;function&quot;){
#                         geo_json_49305be1b31f0cf032f0622a8b3d09a9.resetStyle(e.target);
#                     }
#                 },
#                 mouseover: function(e) {
#                     if(typeof e.target.setStyle === &quot;function&quot;){
#                         const highlightStyle = geo_json_49305be1b31f0cf032f0622a8b3d09a9_highlighter(e.target.feature)
#                         e.target.setStyle(highlightStyle);
#                     }
#                 },
#             });
#         };
#         var geo_json_49305be1b31f0cf032f0622a8b3d09a9 = L.geoJson(null, {
#                 onEachFeature: geo_json_49305be1b31f0cf032f0622a8b3d09a9_onEachFeature,
#
#                 style: geo_json_49305be1b31f0cf032f0622a8b3d09a9_styler,
#                 pointToLayer: geo_json_49305be1b31f0cf032f0622a8b3d09a9_pointToLayer,
#         });
#
#         function geo_json_49305be1b31f0cf032f0622a8b3d09a9_add (data) {
#             geo_json_49305be1b31f0cf032f0622a8b3d09a9
#                 .addData(data);
#         }
#             geo_json_49305be1b31f0cf032f0622a8b3d09a9_add({&quot;bbox&quot;: [-163.01124999999996, 28.647837734345817, -66.82542199999995, 69.74280000000005], &quot;features&quot;: [{&quot;bbox&quot;: [-83.88216999999997, 66.53416000000004, -83.88216999999997, 66.53416000000004], &quot;geometry&quot;: {&quot;coordinates&quot;: [-83.88216999999997, 66.53416000000004], &quot;type&quot;: &quot;Point&quot;}, &quot;id&quot;: &quot;0&quot;, &quot;properties&quot;: {&quot;Age&quot;: &quot; 33&quot;, &quot;Bear&quot;: &quot;Polar&quot;, &quot;Date&quot;: &quot;August 23, 2018&quot;, &quot;Details&quot;: &quot;Three men from Naujaat, whose boat had broken down, were having tea on the mornin
